# %% [markdown]
# ## APS 4 - Ajuste de Curvas

# %%
import math
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## 20.38

# %% [markdown]
# <img src="aps_4_1.JPG">

# %% [markdown]
# ## Plotando os dados para verificar se é linear:

# %%
#pontos dados
x = [0,0.125,0.25,0.375,0.5]
y = [0,6.24,7.75,4.85,0]

# %%
plt.figure(figsize=(5,5))
plt.plot(x,y,color='black')
plt.grid()

# %% [markdown]
# ### Utilizando uma regressão linear,

# %%
#cálculo da regressão
xy = 0
x2 = 0
sx = 0
sy = 0
for i in range(5):
    xy += x[i]*y[i]
    sx += x[i]
    sy += y[i]
    x2 += x[i]**2
    
a1 = (5*xy - (sx*sy))/((5*x2) - (sx**2))
a0 = (sum(y)/5) - a1*(sum(x)/5)



#gráfico 
plt.figure(figsize=(8,8))
ajuste = [a0 + a1*i for i in x]
plt.plot(x, ajuste, color="black")
plt.title("i (A) vs. t (s)")
plt.grid()

# %%
print(a0+a1*0.23)
# Out:
# 3.79024

# %% [markdown]
# ## Em 0,23s, a corrente é de 3.79024 A.

# %% [markdown]
# ## 20.39

# %% [markdown]
# <img src="aps_4_2.JPG">

# %% [markdown]
# <img src="aps_4_3.JPG">

# %% [markdown]
# ## Plotando os dados para verificar se é linear:

# %%
#pontos dados
x = [2,3,4,5,7,10]
y = [5.2,7.8,10.7,13,19.3,27.5]

# %%
plt.figure(figsize=(5,5))
plt.plot(x,y,color='black')
plt.grid()

# %% [markdown]
# ## (a)

# %%
#cálculo da regressão
xy = 0
x2 = 0
sx = 0
sy = 0
for i in range(6):
    xy += x[i]*y[i]
    sx += x[i]
    sy += y[i]
    x2 += x[i]**2
    
a1 = (6*xy - (sx*sy))/((6*x2) - (sx**2))
a0 = (sum(y)/6) - a1*(sum(x)/6)


#gráfico 
plt.figure(figsize=(8,8))
ajuste = [a0 + a1*i for i in x]
plt.plot(x, ajuste, color="black")
plt.title("i (A) vs. V (V)")
plt.grid()

# %%
print(a0 + a1*3.5)
# Out:
# 9.236381322957195

# %% [markdown]
# ## (b)

# %% [markdown]
# ### Para 3,5V, a corrente é de 9.2363 A.

# %% [markdown]
# ## 20.40

# %% [markdown]
# <img src="aps_4_4.JPG">

# %% [markdown]
# ## Plotando os dados para verificar se é linear:

# %%
#pontos dados
x = [1,2,4,6,8,10]
y = [5.5,12.5,17.5,32,38,49]

# %%
plt.figure(figsize=(5,5))
plt.plot(x,y,color='black')
plt.grid()

# %%
#cálculo da regressão
xy = 0
x2 = 0
sx = 0
sy = 0
for i in range(6):
    xy += x[i]*y[i]
    sx += x[i]
    sy += y[i]
    x2 += x[i]**2
    
a1 = (6*xy - (sx*sy))/((6*x2) - (sx**2))
a0 = (sum(y)/6) - a1*(sum(x)/6)



#gráfico 
plt.figure(figsize=(8,8))
ajuste = [a0 + a1*i for i in x]
plt.plot(x, ajuste, color="black")
plt.title("V (V) vs. di/dt (A/s)")
plt.grid()

# %% [markdown]
# ## O significado da regressão destes dados corresponde ao parâmetro L. Mais especificamente, a inclinação da reta plotada corresponde ao parâmetro L.

# %% [markdown]
# ## 20.41

# %% [markdown]
# <img src="aps_4_5.JPG">

# %%
x = [-2,-1,-0.5,0.5,1,2]
y = [-637,-96.5,-20.5,20.5,96.5,637]

# %%
plt.figure(figsize=(5,5))
plt.plot(x,y, color='black')
plt.grid()

# %% [markdown]
# ## De acordo com o perfil da curva, o polinômio utilizado para gerar os dados é de terceiro grau.

# %%
#cálculo da regressão
xy = 0
x2 = 0
sx = 0
sy = 0
for i in range(6):
    xy += x[i]*y[i]
    sx += x[i]
    sy += y[i]
    x2 += x[i]**2
    
a1 = (6*xy - (sx*sy))/((6*x2) - (sx**2))
a0 = (sum(y)/6) - a1*(sum(x)/6)


#gráfico 
plt.figure(figsize=(8,8))
ajuste = [a0 + a1*i for i in x]
plt.plot(x, ajuste, color="black")
plt.title("V (V) vs. i (A)")
plt.grid()

# %%
print(a0 + 0.1*a1)
# Out:
# 26.3

# %% [markdown]
# ## Para i = 0,1A, a tensão é de 26,3 V.

# %% [markdown]
# ## 20.43

# %% [markdown]
# <img src="aps_4_6.JPG">

# %%
x = [200,250,300,375,425,475,600]
y = [7.5,8.6,8.7,10,11.3,12.7,15.3]

# %% [markdown]
# ## Plotando os dados para verificar se é linear:

# %%
plt.figure(figsize=(6,6))
plt.grid()
plt.plot(x,y,'o', color='black')
plt.plot(x,y, color='black')

# %%
xy = 0
x2 = 0
sx = 0
sy = 0
for i in range(7):
    xy += x[i]*y[i]
    sx += x[i]
    sy += y[i]
    x2 += x[i]**2
    
a1 = (7*xy - (sx*sy))/((7*x2) - (sx**2))

a0 = (sum(y)/7) - a1*(sum(x)/7)

# %%
plt.figure(figsize=(8,8))
ajuste = [a0 + a1*i for i in x]
plt.plot(x, ajuste, color="black")
plt.title("deformação % vs T(°C)")
plt.grid()

# %%
print(a0 + a1*400)
# Out:
# 11.072127329192547

# %% [markdown]
# ## Para uma temperatura de 400, a deformação é de 11.07212%.
