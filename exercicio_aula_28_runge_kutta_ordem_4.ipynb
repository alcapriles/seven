# %%
import math
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline

# %% [markdown]
# <img src='seven.JPG'>

# %%
plt.figure(figsize=(7,7))

x = np.linspace(0,2,100).tolist()
y = [math.e**((1/3)*(t**3)-1.1*t) for t in x]

plt.plot(x,y, color='dimgray')
plt.grid()

# %%
def f(t,y):
    return y*(t**2) - 1.1*y

# %%
def ks(ti, yi, h):
    
    k1 = f(ti,yi)
    
    k2 = f(ti + 0.5*h, yi + 0.5*k1*h)
    
    k3 = f(ti + 0.5*h, yi + 0.5*k2*h)
    
    
    k4 = f(ti + h, yi + k3*h)
    
    return k1, k2, k3, k4, h

# %% [markdown]
# ## h = 0.5

# %%
tvals = [0.5*h for h in range(0,5)]
yvals = []
y = 1
k1, k2, k3, k4, h = ks(0,1,0.5)


for i in range(len(tvals)):
    
    y += (1/6)*(k1 + 2*k2 + 2*k3 + k4)*h
    k1, k2, k3, k4, h = ks(tvals[i],y,h)
    yvals.append(y)

    
print(tvals)
print(yvals)

plt.figure(figsize=(7,7))
plt.plot(tvals,yvals, color='dimgray')
plt.grid()
# Out:
# [0.0, 0.5, 1.0, 1.5, 2.0]
# [0.6015702372233073, 0.36188675031290624, 0.2794436835929456, 0.35575677505544895, 0.9531592282747641]

# %% [markdown]
# # Erro para t = 2

# %% [markdown]
# ## h = 0.25

# %%
tvals = [0.25*h for h in range(0,9)]
yvals = []
y = 1
k1, k2, k3, k4, h = ks(0,1,0.5)


for i in range(len(tvals)):
    
    y += (1/6)*(k1 + 2*k2 + 2*k3 + k4)*h
    k1, k2, k3, k4, h = ks(tvals[i],y,h)
    yvals.append(y)

    
print(tvals)
print(yvals)

plt.figure(figsize=(7,7))
plt.plot(tvals,yvals, color='dimgray')
plt.grid()
# Out:
# [0.0, 0.25, 0.5, 0.75, 1.0, 1.25, 1.5, 1.75, 2.0]
# [0.6015702372233073, 0.36188675031290624, 0.2390254037884882, 0.18457193928540527, 0.17739791354514114, 0.2258433928902659, 0.4049940321138563, 1.0850778570425312, 4.574836812124041]

# %% [markdown]
# # Erro para t = 2

# %% [markdown]
# ## h = 0.1

# %%
tvals = [0.1*h for h in range(0,21)]
yvals = []
y = 1
k1, k2, k3, k4, h = ks(0,1,0.5)


for i in range(len(tvals)):
    
    y += (1/6)*(k1 + 2*k2 + 2*k3 + k4)*h
    k1, k2, k3, k4, h = ks(tvals[i],y,h)
    yvals.append(y)

    
print(tvals)
print(yvals)

plt.figure(figsize=(7,7))
plt.plot(tvals,yvals, color='dimgray')
plt.grid()
# Out:
# [0.0, 0.1, 0.2, 0.30000000000000004, 0.4, 0.5, 0.6000000000000001, 0.7000000000000001, 0.8, 0.9, 1.0, 1.1, 1.2000000000000002, 1.3, 1.4000000000000001, 1.5, 1.6, 1.7000000000000002, 1.8, 1.9000000000000001, 2.0]
# [0.6015702372233073, 0.36188675031290624, 0.22429976914673896, 0.144678817583649, 0.09809867040803338, 0.07062698446259733, 0.05453712986790736, 0.045622948538615316, 0.04176247285105964, 0.04225027827909949, 0.047712208022754, 0.06074190348018366, 0.08804148728991291, 0.1467127929816474, 0.28379188795529525, 0.643183283359722, 1.7232449948727737, 5.503891996810045, 21.116898682287683, 97.99204351349798, 553.2320481786036]

# %% [markdown]
# ## Análise

# %% [markdown]
# ### É possível verificar que, ao diminuir-se o passo, o erro também diminui, o que é uma forma de atenuar o erro de truncamento associado ao método.
